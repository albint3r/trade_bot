# %%
from trading_bot.binan import app_factory
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
binan = app_factory()
# Out:
# The DataFrame is Clean Now!

# %%
binan.df.tail(30)
# Out:
#                                open_time      open      high       low  \
# close_time
# 2022-06-23 23:59:59.999000064 2022-06-23  0.052540  0.054703  0.052503
# 2022-06-24 23:59:59.999000064 2022-06-24  0.054229  0.058304  0.054220
# 2022-06-25 23:59:59.999000064 2022-06-25  0.057686  0.058511  0.056360
# 2022-06-26 23:59:59.999000064 2022-06-26  0.057797  0.059159  0.056905
# 2022-06-27 23:59:59.999000064 2022-06-27  0.056937  0.058137  0.056910
# 2022-06-28 23:59:59.999000064 2022-06-28  0.057482  0.058572  0.056229
# 2022-06-29 23:59:59.999000064 2022-06-29  0.056410  0.056758  0.054400
# 2022-06-30 23:59:59.999000064 2022-06-30  0.054671  0.054896  0.053069
# 2022-07-01 23:59:59.999000064 2022-07-01  0.053716  0.055542  0.053231
# 2022-07-02 23:59:59.999000064 2022-07-02  0.054961  0.055603  0.054103
# 2022-07-03 23:59:59.999000064 2022-07-03  0.055416  0.056093  0.054902
# 2022-07-04 23:59:59.999000064 2022-07-04  0.055614  0.057285  0.054780
# ...

# %%
binan.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 binan.plot()
#
# File ~\PycharmProjects\trade_bot\trading_bot\binan\bot.py:127, in BinanceCryptoTrading.plot(self, n_periods)
#     126 def plot(self, n_periods: int = 100) -> None:
# --> 127     self._plot.plot(self.df, self.current_crypto, n_periods)
#
# AttributeError: 'NoneType' object has no attribute 'plot'
