# %% [markdown]
# # Trade Stock Market Bot Predictor, is posible?

# %% [markdown]
# In this paper I would examine if it is possible to predict the stock market prices with a bot and machine learning.
# For this research We will assume that all the assets could be predicted with the same formula (Whatever that means).
# In this case We will use the **Binance Crypto Market API** to get deep in the data.
#
# We won't be using any additional fundamental information, like news or social media (Tweets, posts, etc.).
# The main question to answer is:
#
# ### Is it possible to predict the price of the stocks?
#
# This question is surrounded by another question that could be part of the puzzles that contain the solution.
#
# This are:
#
# - How many days into the future can we predict?
# - What time frame is secure to predict?
# - This apply in any asset (stocks, forex, options, etc)
# - Which model is the best to predict the price of the market?
# - What features need to be used to predict the market?
# - How to evaluate the predicted model results?
#
# Before answering this question, it is important to have a frame theory. And this is because We need to talk about
# the white elephant in the room, **Is it possible to predict Randomness?**
#
# The author of the book 'Black Swan' of  'Nassim Nicholas Taleb' said that it is impossible to predict this kind of situation. Randomness is impossible to predict, this what We call
# 'Black Swan', because it destroys the Average situation.
# This events only could be predicted:
#
# - After the facts
#
# They have a big impact on our lives and that lasts a long time.

# %% [markdown]
# ## Can the price market be predicted?
# Apparently there are many authors that claim it is impossible to predict the next day's price of the market.
# Machine learning models like LSTM could pretend to have a good prediction rate, but when you evaluate the results
# The model only trails the Close price of the Date Before.
#
# For this situation I have some questions, because in any example there are using techniques like Lag Features.
# Maybe We cant predict Black swans but what if We could predict regular behavior
#
# What it happend is that the prediction have a delay of one day, what this means?
# This means that if you hare going to buy or sell, you would enter to late to the 'party', and in the stock market
# this is bad, really bad, your lose your edge and if you dont have a good stop lost, this could produce bad results in real life.
#
# ## What is time lag and why is so important?
# This concept refer to the delay of a event happend in relationship of other. In statistics We could use this to our favor,
# How? Well, if Y have Lag of X We could exploid this, for example, What happend in X could reflect the result in Y.
#
# `A “lag” is a fixed amount of passing time; One set of observations in a time series is plotted (lagged) against a second, later set of data.
# When time series X Granger-causes time series Y (as illustrated below), the patterns in X are approximately repeated in Y after some time lag (two examples are indicated with arrows). Thus, past values of X can be used for the prediction of future values of Y.
# `
# ![image.png](attachment:26b6270b-9509-4c35-9bca-6f93ecd5ea9a.png)
